# %% [markdown]
# # Report1

# %% [markdown]
# ### Import library and read data

# %%
# import library
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

#read data
df = pd.read_excel('/Users/riva5/Downloads/data_query-tbl-details.xlsx')

# %% [markdown]
# Firstly, we import pandas as a tool and read the excel file 'data_query-tbl-details' to start analysis.

# %% [markdown]
# ## I. Types of methodology

# %% [markdown]
# ### Number of Different Types of Methodology

# %%
list(df.columns.values)
df_count = dt[['Sectoral scopes','Methodologies Used']]
df_count['Methodologies Used'] = df_count['Methodologies Used'].str[:3]

df_count['Methodologies Used'].value_counts()
# Out:
# ACM    4330
# AMS    3254
# AM0     520
# AR-      67
# Name: Methodologies Used, dtype: int64

# %% [markdown]
# We use list() to get the name of each column and take out the first three letters of 'Methodologies Used' to classify methodologies - ACM, AMS, or AM for each project.
#
# According to the result, there are 4330 projects using ACM methodology, 3254 projects using AMS methodology, 520 projects using AM methodology, and 67 projects using methodology starting with 'AR'.

# %% [markdown]
# ## II. Project classification methods- Methodology and Project Number

# %% [markdown]
# ### The datafame for the number of projects with different Industry CDM scope and Methodologies.

# %%
# Remove AR- and revise 'AM0' to 'AM'
df_count = df_count[df_count['Methodologies Used']!='AR-']
df_count['Methodologies Used'] = df_count['Methodologies Used'].replace(['AM0'],['AM'])
df_count['Methodologies Used'].value_counts()
# Out:
# ACM    4330
# AMS    3254
# AM      520
# Name: Methodologies Used, dtype: int64

# %% [markdown]
# In order to clearly classify the industries involved in each project with ACM, AMS, or AM, we revise the name whose first three words are 'AMO' to 'AM' and delete the projects starting with 'AR-'.

# %%
df_value_counts =df_count.value_counts()

df_value_counts = df_value_counts.reset_index()
df_value_counts.columns = ['Sectoral scopes','Methodologies Used', 'counts']
df_value_counts
# Out:
#                                       Sectoral scopes Methodologies Used  \
# 0   1 : Energy industries (renewable - / non-renew...                ACM
# 1   1 : Energy industries (renewable - / non-renew...                AMS
# 2   1 : Energy industries (renewable - / non-renew...                AMS
# 3                    13 : Waste handling and disposal                AMS
# 4   1 : Energy industries (renewable - / non-renew...                ACM
# 5                    13 : Waste handling and disposal                ACM
# 6   1 : Energy industries (renewable - / non-renew...                 AM
# 7                                   3 : Energy demand                AMS
# 8                        4 : Manufacturing industries                AMS
# 9   8 : Mining/mineral production\n10 : Fugitive e...                ACM
# 10                            5 : Chemical industries                 AM
# 11    3 : Energy demand\n4 : Manufacturing industries                AMS
# ...

# %% [markdown]
# We use value_counts() to get the number of projects for different CDM scopes with ACM, AMS, or AM and set the index number to view more clearly.

# %% [markdown]
# ### Export to an excel file

# %%
df_value_counts.to_excel('number of project with different methodologies.xlsx', sheet_name='sheet1', index=False)

# %% [markdown]
# Then we export the dataframe to the excel file. For the detailed classification of projects in different industry scopes and methodologies, please refer to the file 'number of project with different methodologies'.
